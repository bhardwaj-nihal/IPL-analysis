# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auction=pd.read_csv("IPL Auction.csv")

# %%
auction.head()
# Out:
#    Unnamed: 0           Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0           0      Rashid Khan  Draft Pick       BOWLER             15.0
# 1           1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           2  Lockie Ferguson        2 Cr       BOWLER             10.0
# 3           3    Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4           4     Shubman Gill  Draft Pick       BATTER              8.0
#
#    Cost IN $ (000) 2021 Squad            Team
# 0           1950.0        SRH  Gujarat Titans
# 1           1950.0         MI  Gujarat Titans
# 2           1300.0        KKR  Gujarat Titans
# 3           1170.0         RR  Gujarat Titans
# 4           1040.0        KKR  Gujarat Titans

# %%
## Total player participated in auction

# %%
auction['Player'].count()
# Out:
# 633

# %%
## Types of player

# %%
auction['TYPE'].value_counts()
# Out:
# ALL-ROUNDER     242
# BOWLER          215
# BATTER          112
# WICKETKEEPER     64
# Name: TYPE, dtype: int64

# %%
## pie graph showing types of player

# %%
labels=['ALL-ROUNDER','BOWLER','BATTER','WICKETKEEPER ']
value=[242,215,112,64]

# %%
plt.pie(value,labels=labels,autopct='%1.0f%%')
plt.show()

# %%
auction['Team'].value_counts()
# Out:
# Unsold                         396
# Chennai Super Kings             25
# Kolkata Knight Riders           25
# Punjab Kings                    25
# Mumbai Indians                  25
# Delhi Capitals                  24
# Rajasthan Royals                24
# Sunrisers Hyderabad             23
# Gujarat Titans                  22
# Lucknow Super Giants            22
# Royal Challengers Bangalore     22
# Name: Team, dtype: int64

# %%
### sorting by price

# %%
sorted=auction.sort_values(by='COST IN ₹ (CR.)',ascending=False)

# %%
sorted
# Out:
#      Unnamed: 0                  Player  Base Price          TYPE  \
# 121         121                KL Rahul  Draft Pick  WICKETKEEPER
# 22           22         Ravindra Jadeja    Retained   ALL-ROUNDER
# 143         143            Rohit Sharma    Retained        BATTER
# 47           47            Rishabh Pant    Retained  WICKETKEEPER
# 144         144            Ishan Kishan        2 Cr  WICKETKEEPER
# ..          ...                     ...         ...           ...
# 628         628            Sairaj Patil     20 Lakh        BATTER
# 629         629              Monu Singh     20 Lakh        BOWLER
# 630         630  Nivethan Radhakrishnan     20 Lakh        BOWLER
# 631         631            Lance Morris     20 Lakh        BOWLER
# 632         632            Aaron Hardie     20 Lakh   ALL-ROUNDER
#
#      COST IN ₹ (CR.)  Cost IN $ (000) 2021 Squad                  Team
# 121            17.00           2210.0       PBKS  Lucknow Super Giants
# ...

# %%
### bar graph of top 10 sold players

# %%
plt.bar(sorted['Player'].head(10),sorted['COST IN ₹ (CR.)'].head(10),color='#000008')
plt.show()

# %%
### total unsold players

# %%
auction[auction['Team']=='Unsold']
# Out:
#      Unnamed: 0                  Player Base Price         TYPE  \
# 237         237            Suresh Raina       2 Cr       BATTER
# 238         238             Steve Smith       2 Cr       BATTER
# 239         239         Shakib Al Hasan       2 Cr  ALL-ROUNDER
# 240         240             Amit Mishra     1.5 Cr       BOWLER
# 241         241             Adil Rashid       2 Cr       BOWLER
# ..          ...                     ...        ...          ...
# 628         628            Sairaj Patil    20 Lakh       BATTER
# 629         629              Monu Singh    20 Lakh       BOWLER
# 630         630  Nivethan Radhakrishnan    20 Lakh       BOWLER
# 631         631            Lance Morris    20 Lakh       BOWLER
# 632         632            Aaron Hardie    20 Lakh  ALL-ROUNDER
#
#      COST IN ₹ (CR.)  Cost IN $ (000) 2021 Squad    Team
# 237              NaN              NaN        CSK  Unsold
# 238              NaN              NaN         DC  Unsold
# ...

# %%
auction['Base Price'].value_counts()
# Out:
# 20 Lakh       344
# 50 Lakh       104
# 2 Cr           48
# 1 Cr           33
# Retained       27
# 75 Lakh        26
# 1.5 Cr         20
# 40 Lakh        16
# 30 Lakh         9
# Draft Pick      6
# Name: Base Price, dtype: int64

# %%
## player auction in more than 1o.cr

# %%
auction[auction['COST IN ₹ (CR.)']>10.0]['Player']
# Out:
# 0            Rashid Khan
# 1          Hardik Pandya
# 22       Ravindra Jadeja
# 23         Deepak Chahar
# 24              MS Dhoni
# 47          Rishabh Pant
# 48        Shardul Thakur
# 71          Shreyas Iyer
# 72         Andre Russell
# 96        Mayank Agarwal
# 97      Liam Livingstone
# 121             KL Rahul
# 143         Rohit Sharma
# 144         Ishan Kishan
# 145       Jasprit Bumrah
# 168          Virat Kohli
# 169        Glenn Maxwell
# 170    Wanindu Hasaranga
# 171        Harshal Patel
# 190         Sanju Samson
# 214      Kane Williamson
# 215      Nicholas Pooran
# Name: Player, dtype: object

# %%
## player auction in highiest price

# %%
auction['COST IN ₹ (CR.)'].max()
# Out:
# 17.0

# %%
auction[auction['COST IN ₹ (CR.)']==17.0]['Player']
# Out:
# 121    KL Rahul
# Name: Player, dtype: object

# %%
## player auction in lowest price

# %%
auction['COST IN ₹ (CR.)'].min()
# Out:
# 0.2

# %%
auction[auction['COST IN ₹ (CR.)']==0.2]['Player']
# Out:
# 20        Darshan Nalkande
# 21         Pradeep Sangwan
# 39         K.Bhagath Varma
# 40         Simarjeet Singh
# 41           N. Jagadeesan
# 42        C.Hari Nishaanth
# 43               K.M. Asif
# 44        Tushar Deshpande
# 45     Subhranshu Senapati
# 46        Mukesh Choudhary
# 67           Ashwin Hebbar
# 68           Sarfaraz Khan
# 69             Ripal Patel
# 70            Vicky Ostwal
# 90              Rasikh Dar
# 91              Anukul Roy
# 92          Baba Indrajith
# 93               Aman Khan
# 94            Ramesh Kumar
# 95           Pratham Singh
# 115          Prerak Mankad
# 116             Ansh Patel
# 117          Jitesh Sharma
# 118    Writtick Chatterjee
# 119          Atharva Taide
# 120          Baltej Dhanda
# 137            Manan Vohra
# 138       B. Sai Sudharsan
# 139           Karan Sharma
# 140           Ayush Badoni
# 141            Mohsin Khan
# 142           Mayank Yadav
# 162       Anmolpreet Singh
# 163            Aryan Juyal
# ...

# %%
auction.head()
# Out:
#    Unnamed: 0           Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0           0      Rashid Khan  Draft Pick       BOWLER             15.0
# 1           1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           2  Lockie Ferguson        2 Cr       BOWLER             10.0
# 3           3    Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4           4     Shubman Gill  Draft Pick       BATTER              8.0
#
#    Cost IN $ (000) 2021 Squad            Team
# 0           1950.0        SRH  Gujarat Titans
# 1           1950.0         MI  Gujarat Titans
# 2           1300.0        KKR  Gujarat Titans
# 3           1170.0         RR  Gujarat Titans
# 4           1040.0        KKR  Gujarat Titans

# %%
### Bowler auction

# %%
Bowler=auction[auction['TYPE']=='BOWLER']

# %%
Bowler
# Out:
#      Unnamed: 0                  Player  Base Price    TYPE  COST IN ₹ (CR.)  \
# 0             0             Rashid Khan  Draft Pick  BOWLER            15.00
# 2             2         Lockie Ferguson        2 Cr  BOWLER            10.00
# 5             5          Mohammad Shami        2 Cr  BOWLER             6.25
# 6             6              Yash Dayal     20 Lakh  BOWLER             3.20
# 8             8          R. Sai Kishore     20 Lakh  BOWLER             3.00
# ..          ...                     ...         ...     ...              ...
# 561         561            Liam Hatcher     20 Lakh  BOWLER              NaN
# 627         627           Mihir Hirwani     20 Lakh  BOWLER              NaN
# 629         629              Monu Singh     20 Lakh  BOWLER              NaN
# 630         630  Nivethan Radhakrishnan     20 Lakh  BOWLER              NaN
# 631         631            Lance Morris     20 Lakh  BOWLER              NaN
#
# ...

# %%
Bowler['COST IN ₹ (CR.)'].max()
# Out:
# 15.0

# %%
Bowler[Bowler['COST IN ₹ (CR.)']==15.0]['Player']
# Out:
# 0    Rashid Khan
# Name: Player, dtype: object

# %%
Bowler[Bowler['COST IN ₹ (CR.)']==Bowler['COST IN ₹ (CR.)'].max()]['Player']
# Out:
# 0    Rashid Khan
# Name: Player, dtype: object

# %%
Bowler['COST IN ₹ (CR.)'].min()
# Out:
# 0.2

# %%
Bowler[Bowler['COST IN ₹ (CR.)']==0.2]['Player']
# Out:
# 40        Simarjeet Singh
# 43              K.M. Asif
# 44       Tushar Deshpande
# 46       Mukesh Choudhary
# 90             Rasikh Dar
# 120         Baltej Dhanda
# 141           Mohsin Khan
# 142          Mayank Yadav
# 187            Akash Deep
# 209           Kuldeep Sen
# 211          Tejas Baroka
# 212          Kuldip Yadav
# 234    Jagadeesha Suchith
# 236         Saurabh Dubey
# Name: Player, dtype: object

# %%
### all-rounder auction

# %%
allrounder=auction[auction['TYPE']=='ALL-ROUNDER']

# %%
allrounder
# Out:
#      Unnamed: 0            Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 1             1     Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 3             3     Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 14           14      Jayant Yadav        1 Cr  ALL-ROUNDER              1.7
# 15           15     Vijay Shankar     50 Lakh  ALL-ROUNDER              1.4
# 16           16    Dominic Drakes     75 Lakh  ALL-ROUNDER              1.1
# ..          ...               ...         ...          ...              ...
# 622         622  Dunith Wellalage     20 Lakh  ALL-ROUNDER              NaN
# 623         623   Agnivesh Ayachi     20 Lakh  ALL-ROUNDER              NaN
# 624         624        Rohan Rana     20 Lakh  ALL-ROUNDER              NaN
# 625         625      Nitish Reddy     20 Lakh  ALL-ROUNDER              NaN
# 632         632      Aaron Hardie     20 Lakh  ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2021 Squad            Team
# ...

# %%
allrounder['COST IN ₹ (CR.)'].max()
# Out:
# 16.0

# %%
allrounder[allrounder['COST IN ₹ (CR.)']==16.0]['Player']
# Out:
# 22    Ravindra Jadeja
# Name: Player, dtype: object

# %%
allrounder['COST IN ₹ (CR.)'].min()
# Out:
# 0.2

# %%
allrounder[allrounder['COST IN ₹ (CR.)']==0.2]['Player']
# Out:
# 20        Darshan Nalkande
# 21         Pradeep Sangwan
# 39         K.Bhagath Varma
# 68           Sarfaraz Khan
# 69             Ripal Patel
# 70            Vicky Ostwal
# 91              Anukul Roy
# 93               Aman Khan
# 115          Prerak Mankad
# 116             Ansh Patel
# 118    Writtick Chatterjee
# 119          Atharva Taide
# 138       B. Sai Sudharsan
# 139           Karan Sharma
# 140           Ayush Badoni
# 164        Ramandeep Singh
# 166        Hrithik Shokeen
# 167      Mohd. Arshad Khan
# 188       Aneeshwar Gautam
# 208           Anunay Singh
# 213        Shubham Garhwal
# 235         Shashank Singh
# Name: Player, dtype: object

# %%
### batter auction

# %%
batter=auction[auction['TYPE']=='BATTER']

# %%
batter
# Out:
#      Unnamed: 0               Player  Base Price    TYPE  COST IN ₹ (CR.)  \
# 4             4         Shubman Gill  Draft Pick  BATTER              8.0
# 7             7         David Miller        1 Cr  BATTER              3.0
# 9             9  Abhinav Sadarangani     20 Lakh  BATTER              2.6
# 12           12            Jason Roy        2 Cr  BATTER              2.0
# 27           27      Ruturaj Gaikwad    Retained  BATTER              6.0
# ..          ...                  ...         ...     ...              ...
# 483         483          Henan Malik     20 Lakh  BATTER              NaN
# 484         484         Pukhraj Mann     20 Lakh  BATTER              NaN
# 485         485       Shashwat Rawat     20 Lakh  BATTER              NaN
# 486         486      Jake Weatherald     20 Lakh  BATTER              NaN
# 628         628         Sairaj Patil     20 Lakh  BATTER              NaN
#
#      Cost IN $ (000) 2021 Squad                 Team
# ...

# %%
batter['COST IN ₹ (CR.)'].max()
# Out:
# 16.0

# %%
batter[batter['COST IN ₹ (CR.)']==16.0]['Player']
# Out:
# 143    Rohit Sharma
# Name: Player, dtype: object

# %%
batter['COST IN ₹ (CR.)'].min()
# Out:
# 0.2

# %%
batter[batter['COST IN ₹ (CR.)']==0.2]['Player']
# Out:
# 42        C.Hari Nishaanth
# 45     Subhranshu Senapati
# 67           Ashwin Hebbar
# 94            Ramesh Kumar
# 95           Pratham Singh
# 137            Manan Vohra
# 162       Anmolpreet Singh
# 165           Rahul Buddhi
# 232            Priyam Garg
# 233              R Samarth
# Name: Player, dtype: object

# %%
## wicket-keeper auction

# %%
wicketkeeper=auction[auction['TYPE']=='WICKETKEEPER']

# %%
wicketkeeper
# Out:
#      Unnamed: 0               Player Base Price          TYPE  \
# 10           10         Matthew Wade       2 Cr  WICKETKEEPER
# 13           13      Wriddhiman Saha       1 Cr  WICKETKEEPER
# 24           24             MS Dhoni   Retained  WICKETKEEPER
# 26           26        Ambati Rayudu       2 Cr  WICKETKEEPER
# 41           41        N. Jagadeesan    20 Lakh  WICKETKEEPER
# ..          ...                  ...        ...           ...
# 439         439         Fazil Makaya    20 Lakh  WICKETKEEPER
# 440         440       Ryan Rickelton    20 Lakh  WICKETKEEPER
# 441         441  Sandeep Kumar Tomar    20 Lakh  WICKETKEEPER
# 442         442        Siddhesh Wath    20 Lakh  WICKETKEEPER
# 626         626        Hardik Tamore    20 Lakh  WICKETKEEPER
#
#      COST IN ₹ (CR.)  Cost IN $ (000) 2021 Squad                 Team
# 10              2.40            312.0        NaN       Gujarat Titans
# 13              1.90            247.0        SRH       Gujarat Titans
# ...

# %%
wicketkeeper['COST IN ₹ (CR.)'].max()
# Out:
# 17.0

# %%
wicketkeeper[wicketkeeper['COST IN ₹ (CR.)']==17.0]['Player']
# Out:
# 121    KL Rahul
# Name: Player, dtype: object

# %%
wicketkeeper['COST IN ₹ (CR.)'].min()
# Out:
# 0.2

# %%
wicketkeeper[wicketkeeper['COST IN ₹ (CR.)']==0.2]['Player']
# Out:
# 41       N. Jagadeesan
# 92      Baba Indrajith
# 117      Jitesh Sharma
# 163        Aryan Juyal
# 189    Luvnith Sisodia
# 210        Dhruv Jurel
# Name: Player, dtype: object

# %%
auction.isnull().sum()
# Out:
# Unnamed: 0           0
# Player               0
# Base Price           0
# TYPE                 0
# COST IN ₹ (CR.)    396
# Cost IN $ (000)    396
# 2021 Squad         434
# Team                 0
# dtype: int64

# %% [markdown]
# ## analysis of batting

# %%
batting=pd.read_csv("batting.csv")

# %%
batting
# Out:
#       MatchID  InningsNo Team        PlayerName  MatchPlayingOrder  \
# 0           1          1  CSK  Ruturaj  Gaikwad                  1
# 1           1          1  CSK      Devon Conway                  2
# 2           1          1  CSK     Robin Uthappa                  3
# 3           1          1  CSK     Ambati Rayudu                  4
# 4           1          1  CSK   Ravindra Jadeja                  5
# ...       ...        ...  ...               ...                ...
# 1623       76          2   GT       Rashid Khan                  7
# 1624       76          2   GT       Sai Kishore                  8
# 1625       76          2   GT    Mohammad Shami                  9
# 1626       76          2   GT   Lockie Ferguson                 10
# 1627       76          2   GT        Yash Dayal                 11
#
#                BowlerName                                   OutDesc  Runs  \
# 0             Umesh Yadav               c Nitish Rana b Umesh Yadav     0
# ...

# %%
batting['PlayerName'].value_counts()
# Out:
# Ravichandran Ashwin    17
# Yuzvendra Chahal       17
# Prasidh Krishna        17
# Riyan Parag            17
# Devdutt Padikkal       17
#                        ..
# Aman Khan               1
# Nathan Coulter-Nile     1
# Adam Milne              1
# Simran Singh            1
# Prerak Mankad           1
# Name: PlayerName, Length: 190, dtype: int64

# %%
batting.isnull().sum()
# Out:
# MatchID                0
# InningsNo              0
# Team                   0
# PlayerName             0
# MatchPlayingOrder      0
# BowlerName           716
# OutDesc              452
# Runs                   0
# Balls                  0
# DotBalls               0
# Ones                   0
# Twos                   0
# Threes                 0
# Fours                  0
# Sixes                  0
# StrikeRate             0
# WicketNo             717
# AgainstFast            0
# AgainstSpin            0
# dtype: int64

# %%
### higest strike rate

# %%
batting['StrikeRate'].max()
# Out:
# '96.88'

# %%
batting[batting['StrikeRate']==batting['StrikeRate'].max()]
# Out:
#       MatchID  InningsNo Team        PlayerName  MatchPlayingOrder  \
# 1136       52          2   RR  Devdutt Padikkal                  2
#
#           BowlerName                            OutDesc  Runs  Balls  \
# 1136  Arshdeep Singh  c Mayank Agarwal b Arshdeep Singh    31     32
#
#       DotBalls  Ones  Twos  Threes  Fours  Sixes StrikeRate  WicketNo  \
# 1136        11    17     1       0      3      0      96.88       4.0
#
#       AgainstFast  AgainstSpin
# 1136           22           10

# %%
batting.dtypes
# Out:
# MatchID                int64
# InningsNo              int64
# Team                  object
# PlayerName            object
# MatchPlayingOrder      int64
# BowlerName            object
# OutDesc               object
# Runs                   int64
# Balls                  int64
# DotBalls               int64
# Ones                   int64
# Twos                   int64
# Threes                 int64
# Fours                  int64
# Sixes                  int64
# StrikeRate            object
# WicketNo             float64
# AgainstFast            int64
# AgainstSpin            int64
# dtype: object

# %%
### minimum strike rate

# %%
batting['StrikeRate'].min()
# Out:
# '-'

# %%
batting[batting['StrikeRate']==batting['StrikeRate'].min()]
# Out:
#       MatchID  InningsNo Team        PlayerName  MatchPlayingOrder BowlerName  \
# 7           1          1  CSK      Dwayne Bravo                  8        NaN
# 8           1          1  CSK        Adam Milne                  9        NaN
# 9           1          1  CSK  Tushar Deshpande                 10        NaN
# 10          1          1  CSK  Mitchell Santner                 11        NaN
# 17          1          2  KKR     Andre Russell                  5        NaN
# ...       ...        ...  ...               ...                ...        ...
# 1623       76          2   GT       Rashid Khan                  7        NaN
# 1624       76          2   GT       Sai Kishore                  8        NaN
# 1625       76          2   GT    Mohammad Shami                  9        NaN
# 1626       76          2   GT   Lockie Ferguson                 10        NaN
# 1627       76          2   GT        Yash Dayal                 11        NaN
#
# ...

# %%
### maximum sixes

# %%
batting['Sixes'].max()
# Out:
# 10

# %%
batting[batting['Sixes']==batting['Sixes'].max()]
# Out:
#       MatchID  InningsNo Team       PlayerName  MatchPlayingOrder BowlerName  \
# 1430       66          1  LSG  Quinton De Kock                  1        NaN
#
#       OutDesc  Runs  Balls  DotBalls  Ones  Twos  Threes  Fours  Sixes  \
# 1430  not out   140     70        15    30     5       0     10     10
#
#      StrikeRate  WicketNo  AgainstFast  AgainstSpin
# 1430     200.00       NaN           42           28

# %%
### maximum fours

# %%
batting['Fours'].max()
# Out:
# 13

# %%
batting[batting['Fours']==batting['Fours'].max()]
# Out:
#       MatchID  InningsNo Team PlayerName  MatchPlayingOrder  BowlerName  \
# 1476       68          1  CSK  Moeen Ali                  3  Obed McCoy
#
#                          OutDesc  Runs  Balls  DotBalls  Ones  Twos  Threes  \
# 1476  c Riyan Parag b Obed McCoy    93     57        19    21     1       0
#
#       Fours  Sixes StrikeRate  WicketNo  AgainstFast  AgainstSpin
# 1476     13      3     163.16       2.0           33           24

# %%
decock=batting[batting['PlayerName']=='Quinton De Kock']

# %%
decock
# Out:
#       MatchID  InningsNo Team       PlayerName  MatchPlayingOrder  \
# 67          4          1  LSG  Quinton De Kock                  4
# 144         7          2  LSG  Quinton De Kock                  2
# 243        12          1  LSG  Quinton De Kock                  2
# 320        15          2  LSG  Quinton De Kock                  2
# 430        20          2  LSG  Quinton De Kock                  2
# 551        26          1  LSG  Quinton De Kock                  2
# 671        31          2  LSG  Quinton De Kock                  2
# 792        37          1  LSG  Quinton De Kock                  1
# 902        42          1  LSG  Quinton De Kock                  2
# 968        45          1  LSG  Quinton De Kock                  2
# 1144       53          1  LSG  Quinton De Kock                  2
# 1243       57          2  LSG  Quinton De Kock                  2
# 1375       63          2  LSG  Quinton De Kock                  2
# ...

# %%
### total sixes by decock

# %%
decock['Sixes'].sum()
# Out:
# 23

# %%
batting1=batting.groupby('PlayerName').sum()

# %%
batting1
# Out:
#                    MatchID  InningsNo  MatchPlayingOrder  Runs  Balls  \
# PlayerName
# Aaron Finch            196          8                  5    86     61
# Abdul Samad             17          4                 12     4      7
# Abhijeet Tomar          66          2                  2     4      8
# Abhinav Manohar        179         12                 49   108     75
# Abhishek Sharma        530         25                 22   426    320
# ...                    ...        ...                ...   ...    ...
# Washington Sundar      337         15                 67   101     69
# Wriddhiman Saha        581         18                 17   317    259
# Yash Dayal             463         14                 96     0      1
# Yashasvi Jaiswal       492         13                 22   258    194
# Yuzvendra Chahal       730         21                177     5      8
#
#                    DotBalls  Ones  Twos  Threes  Fours  Sixes  WicketNo  \
# PlayerName
# ...

# %%
### who it most sixes

# %%
batting1['Sixes'].max()
# Out:
# 45

# %%
batting1[batting1['Sixes']==45]
# Out:
#              MatchID  InningsNo  MatchPlayingOrder  Runs  Balls  DotBalls  \
# PlayerName
# Jos Buttler      730         21                 17   863    579       230
#
#              Ones  Twos  Threes  Fours  Sixes  WicketNo  AgainstFast  \
# PlayerName
# Jos Buttler   185    33       2     83     45      63.0          416
#
#              AgainstSpin
# PlayerName
# Jos Buttler          158

# %%
## who it most runs

# %%
batting1['Runs'].max()
# Out:
# 863

# %%
batting1[batting1['Runs']==863]
# Out:
#              MatchID  InningsNo  MatchPlayingOrder  Runs  Balls  DotBalls  \
# PlayerName
# Jos Buttler      730         21                 17   863    579       230
#
#              Ones  Twos  Threes  Fours  Sixes  WicketNo  AgainstFast  \
# PlayerName
# Jos Buttler   185    33       2     83     45      63.0          416
#
#              AgainstSpin
# PlayerName
# Jos Buttler          158

# %% [markdown]
# ## bowler data analysis

# %%
bowler=pd.read_csv('bowling.csv')

# %%
bowler
# Out:
#      MatchID  InningsNo Team           PlayerName  Overs  Maidens  Runs  \
# 0          1          1  KKR          Umesh Yadav    4.0        0    20
# 1          1          1  KKR          Shivam Mavi    4.0        0    35
# 2          1          1  KKR  Varun Chakaravarthy    4.0        0    23
# 3          1          1  KKR         Sunil Narine    4.0        0    15
# 4          1          1  KKR        Andre Russell    4.0        0    38
# ..       ...        ...  ...                  ...    ...      ...   ...
# 852       76          2   RR          Trent Boult    4.0        1    14
# 853       76          2   RR      Prasidh Krishna    4.0        0    40
# 854       76          2   RR     Yuzvendra Chahal    4.0        0    20
# 855       76          2   RR           Obed McCoy    3.1        0    26
# 856       76          2   RR  Ravichandran Ashwin    3.0        0    32
#
#      Wickets  Wides  NoBalls  Economy  BowlingOrder  TotalLegalBallsBowled  \
# ...

# %%
#### maximum wickets in 1 inning

# %%
bowler['Wickets'].max()
# Out:
# 5

# %%
bowler[bowler['Wickets']==5]['PlayerName']
# Out:
# 351     Yuzvendra Chahal
# 463          Umran Malik
# 628    Wanindu Hasaranga
# 642       Jasprit Bumrah
# Name: PlayerName, dtype: object

# %%
bowler1=bowler.groupby('PlayerName').sum()

# %%
bowler
# Out:
#      MatchID  InningsNo Team           PlayerName  Overs  Maidens  Runs  \
# 0          1          1  KKR          Umesh Yadav    4.0        0    20
# 1          1          1  KKR          Shivam Mavi    4.0        0    35
# 2          1          1  KKR  Varun Chakaravarthy    4.0        0    23
# 3          1          1  KKR         Sunil Narine    4.0        0    15
# 4          1          1  KKR        Andre Russell    4.0        0    38
# ..       ...        ...  ...                  ...    ...      ...   ...
# 852       76          2   RR          Trent Boult    4.0        1    14
# 853       76          2   RR      Prasidh Krishna    4.0        0    40
# 854       76          2   RR     Yuzvendra Chahal    4.0        0    20
# 855       76          2   RR           Obed McCoy    3.1        0    26
# 856       76          2   RR  Ravichandran Ashwin    3.0        0    32
#
#      Wickets  Wides  NoBalls  Economy  BowlingOrder  TotalLegalBallsBowled  \
# ...

# %%
### player who take maximum wickets

# %%
bowler1['Wickets'].max()
# Out:
# 27

# %%
bowler1[bowler1['Wickets']==27]
# Out:
#                   MatchID  InningsNo  Overs  Maidens  Runs  Wickets  Wides  \
# PlayerName
# Yuzvendra Chahal      730         30   68.0        0   527       27     21
#
#                   NoBalls  Economy  BowlingOrder  TotalLegalBallsBowled  \
# PlayerName
# Yuzvendra Chahal        0   131.75            78                    408
#
#                   DotBalls  Ones  Twos  Threes  Fours  Sixes  StrikeRate
# PlayerName
# Yuzvendra Chahal       137   197    19       3     25     27       206.8

# %%
### who throw maximum no balls

# %%
bowler1['NoBalls'].max()
# Out:
# 5

# %%
bowler1[bowler1['NoBalls']==5]
# Out:
#              MatchID  InningsNo  Overs  Maidens  Runs  Wickets  Wides  \
# PlayerName
# Umesh Yadav      353         16   48.0        2   339       16      4
#
#              NoBalls  Economy  BowlingOrder  TotalLegalBallsBowled  DotBalls  \
# PlayerName
# Umesh Yadav        5    84.75            12                    288       143
#
#              Ones  Twos  Threes  Fours  Sixes  StrikeRate
# PlayerName
# Umesh Yadav    86    10       2     36     13       158.0

# %%
### maximum economy

# %%
bowler1['Economy'].max()
# Out:
# 156.75

# %%
bowler1[bowler1['Economy']==156.75]
# Out:
#                 MatchID  InningsNo  Overs  Maidens  Runs  Wickets  Wides  \
# PlayerName
# Mohammed Siraj      550         24   51.0        0   514        9     16
#
#                 NoBalls  Economy  BowlingOrder  TotalLegalBallsBowled  \
# PlayerName
# Mohammed Siraj        3   156.75            28                    306
#
#                 DotBalls  Ones  Twos  Threes  Fours  Sixes  StrikeRate
# PlayerName
# Mohammed Siraj       129    83    19       1     47     31       108.0

# %%
#### bowler who gives maximum sixes

# %%
bowler1['Sixes'].max()
# Out:
# 31

# %%
bowler1[bowler1['Sixes']==31]
# Out:
#                 MatchID  InningsNo  Overs  Maidens  Runs  Wickets  Wides  \
# PlayerName
# Mohammed Siraj      550         24   51.0        0   514        9     16
#
#                 NoBalls  Economy  BowlingOrder  TotalLegalBallsBowled  \
# PlayerName
# Mohammed Siraj        3   156.75            28                    306
#
#                 DotBalls  Ones  Twos  Threes  Fours  Sixes  StrikeRate
# PlayerName
# Mohammed Siraj       129    83    19       1     47     31       108.0

# %%
#### bowler who gives maximum fours

# %%
bowler1['Fours'].max()
# Out:
# 71

# %%
bowler1[bowler1['Fours']==71]
# Out:
#                  MatchID  InningsNo  Overs  Maidens  Runs  Wickets  Wides  \
# PlayerName
# Prasidh Krishna      730         30   66.3        3   551       19     30
#
#                  NoBalls  Economy  BowlingOrder  TotalLegalBallsBowled  \
# PlayerName
# Prasidh Krishna        3   140.85            34                    399
#
#                  DotBalls  Ones  Twos  Threes  Fours  Sixes  StrikeRate
# PlayerName
# Prasidh Krishna       200   100    15       1     71     18       220.0

# %%
### bowler who throw maximum overs

# %%
bowler1['Overs'].max()
# Out:
# 68.0

# %%
bowler1[bowler1['Overs']==68.0]
# Out:
#                   MatchID  InningsNo  Overs  Maidens  Runs  Wickets  Wides  \
# PlayerName
# Yuzvendra Chahal      730         30   68.0        0   527       27     21
#
#                   NoBalls  Economy  BowlingOrder  TotalLegalBallsBowled  \
# PlayerName
# Yuzvendra Chahal        0   131.75            78                    408
#
#                   DotBalls  Ones  Twos  Threes  Fours  Sixes  StrikeRate
# PlayerName
# Yuzvendra Chahal       137   197    19       3     25     27       206.8
